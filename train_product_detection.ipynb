# %%
# yolo setup
# !git clone https://github.com/ultralytics/yolov5 # clone repo
# !pip install -U -r yolov5/requirements.txt # install dependencies
# !pip install facenet-pytorch
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'yolov5/requirements.txt'
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# ...

# %%
# load train/valid data
import zipfile
with zipfile.ZipFile('hackathon.zip', 'r') as zip_ref:
    zip_ref.extractall('content3/')

# %%
# load test data
import zipfile
with zipfile.ZipFile('test.zip', 'r') as zip_ref:
    zip_ref.extractall('content3/test/')

# %%
# train model on augmented data
# !python yolov5/train.py --img 416 --batch 16 --epochs 100 --data /home/ubuntu/content3/data.yaml --cfg yolov5/models/yolov5m.yaml --weights runs/train/exp16/weights/best.pt
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# github: skipping check (not a git repository)
# YOLOv5 🚀 v4.0-184-g9ccfa85 torch 1.8.1+cu102 CPU
#
# ...

# %%
# train model on adjusted data
# !python yolov5/train.py --img 416 --batch 16 --epochs 10 --data /home/ubuntu/content3/data.yaml --cfg yolov5/models/yolov5m.yaml --weights runs/train/exp17/weights/best.pt
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# github: skipping check (not a git repository)
# YOLOv5 🚀 v4.0-184-g9ccfa85 torch 1.8.1+cu102 CPU
#
# ...

# %%
# run detection on validation images for analysis
# !python yolov5/detect.py --weights runs/train/exp17/weights/best.pt --source /home/ubuntu/content3/valid/images/ --img 416 --iou-thres 0.3 --conf-thres 0.3 --save-txt
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.3, device='', exist_ok=False, img_size=416, iou_thres=0.3, name='exp', nosave=False, project='runs/detect', save_conf=False, save_txt=True, source='/home/ubuntu/content3/valid/images/', update=False, view_img=False, weights=['runs/train/exp17/weights/best.pt'])
# YOLOv5 🚀 v4.0-184-g9ccfa85 torch 1.8.1+cu102 CPU
#
# Fusing layers...
# Model Summary: 308 layers, 21195237 parameters, 0 gradients, 50.8 GFLOPS
# image 1/40 /home/ubuntu/content3/valid/images/front_fr-11-400_jpg.rf.b94df5647f583ba64bc3c6e8bba38d50.jpg: 416x416 1 3700214617892, Done. (0.324s)
# ...

# %%
# run detection on "in the wild" test images for analysis
# !python yolov5/detect.py --weights runs/train/exp18/weights/best.pt --source /home/ubuntu/content3/test/ --img 416 --iou-thres 0.2 --conf-thres 0.25 --save-txt
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=416, iou_thres=0.2, name='exp', nosave=False, project='runs/detect', save_conf=False, save_txt=True, source='/home/ubuntu/content3/test/', update=False, view_img=False, weights=['runs/train/exp18/weights/best.pt'])
# YOLOv5 🚀 v4.0-184-g9ccfa85 torch 1.8.1+cu102 CPU
#
# Fusing layers...
# Model Summary: 308 layers, 21195237 parameters, 0 gradients, 50.8 GFLOPS
# image 1/40 /home/ubuntu/content3/test/1.jpg: 320x416 Done. (0.245s)
# image 2/40 /home/ubuntu/content3/test/10.jpg: 416x416 Done. (0.307s)
# image 3/40 /home/ubuntu/content3/test/11.jpg: 416x416 Done. (0.300s)
# ...

# %%
# load final data (valid - official images; train - augmentations and "in the wild" images)
import zipfile
with zipfile.ZipFile('final_data.zip', 'r') as zip_ref:
    zip_ref.extractall('content3/')

# %%
# final training
# !python yolov5/train.py --img 416 --batch 16 --epochs 20 --data /home/ubuntu/content3/data.yaml --cfg yolov5/models/yolov5m.yaml --weights runs/train/exp18/weights/best.pt
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# github: skipping check (not a git repository)
# YOLOv5 🚀 v4.0-184-g9ccfa85 torch 1.8.1+cu102 CPU
#
# ...

# %%
# run detection on "in the wild" test images for analysis
# !python yolov5/detect.py --weights runs/train/exp23/weights/best.pt --source /home/ubuntu/content3/archive2/valid/images --img 416 --iou-thres 0.2 --conf-thres 0.25 --save-txt
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=416, iou_thres=0.2, name='exp', nosave=False, project='runs/detect', save_conf=False, save_txt=True, source='/home/ubuntu/content3/archive2/valid/images', update=False, view_img=False, weights=['runs/train/exp23/weights/best.pt'])
# YOLOv5 🚀 v4.0-184-g9ccfa85 torch 1.8.1+cu102 CPU
#
# Fusing layers...
# Model Summary: 308 layers, 21195237 parameters, 0 gradients, 50.8 GFLOPS
# image 1/40 /home/ubuntu/content3/archive2/valid/images/10_jpg.rf.eafbbbd01b23f636f09dc78b0254fa87.jpg: 416x416 Done. (0.319s)
# ...

# %%
# run detection on "in the wild" test images for analysis
# !python yolov5/detect.py --weights runs/train/exp23/weights/best.pt --source /home/ubuntu/content3/valid/images --img 416 --iou-thres 0.2 --conf-thres 0.25 --save-txt
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=416, iou_thres=0.2, name='exp', nosave=False, project='runs/detect', save_conf=False, save_txt=True, source='/home/ubuntu/content3/valid/images', update=False, view_img=False, weights=['runs/train/exp23/weights/best.pt'])
# YOLOv5 🚀 v4.0-184-g9ccfa85 torch 1.8.1+cu102 CPU
#
# Fusing layers...
# Model Summary: 308 layers, 21195237 parameters, 0 gradients, 50.8 GFLOPS
# image 1/40 /home/ubuntu/content3/valid/images/front_fr-11-400_jpg.rf.892ea5e827af0342eebf79e136b23cc3.jpg: 416x256 1 3700214617892, Done. (0.202s)
# ...
